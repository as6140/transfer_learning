# %% [markdown]
# # Imports & Data Loading

# %%
#!pip install tensorflow-hub

# %%
import pandas as pd
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub

import tensorflow.keras as keras 
from keras.layers import Input, Lambda, Dense
from keras.models import Model
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
import spacy
from tqdm import tqdm
import re
import time
import pickle

# %%
raw_df = pd.read_csv('data/Political-media-DFE.csv',encoding='latin')
raw_df.head().T
# Out:
#                                                                      0  \
# _unit_id                                                     766192484
# _golden                                                          False
# _unit_state                                                  finalized
# _trusted_judgments                                                   1
# _last_judgment_at                                         8/4/15 21:17
# audience                                                      national
# audience:confidence                                                  1
# bias                                                          partisan
# bias:confidence                                                      1
# message                                                         policy
# message:confidence                                                   1
# orig__golden                                                       NaN
# audience_gold                                                      NaN
# bias_gold                                                          NaN
# bioid                                                          R000596
# embed                <blockquote class="twitter-tweet" width="450">...
# id                                                         3.83249E+17
# label                   From: Trey Radel (Representative from Florida)
# message_gold                                                       NaN
# source                                                         twitter
# text                 RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...
#
#                                                                      1  \
# _unit_id                                                     766192485
# _golden                                                          False
# _unit_state                                                  finalized
# _trusted_judgments                                                   1
# _last_judgment_at                                         8/4/15 21:20
# audience                                                      national
# audience:confidence                                                  1
# bias                                                          partisan
# bias:confidence                                                      1
# message                                                         attack
# message:confidence                                                   1
# orig__golden                                                       NaN
# audience_gold                                                      NaN
# bias_gold                                                          NaN
# bioid                                                          M000355
# embed                <blockquote class="twitter-tweet" width="450">...
# id                                                         3.11208E+17
# label                    From: Mitch McConnell (Senator from Kentucky)
# message_gold                                                       NaN
# source                                                         twitter
# text                 VIDEO - #Obamacare:  Full of Higher Costs and ...
#
#                                                                      2  \
# _unit_id                                                     766192486
# _golden                                                          False
# _unit_state                                                  finalized
# _trusted_judgments                                                   1
# _last_judgment_at                                         8/4/15 21:14
# audience                                                      national
# audience:confidence                                                  1
# bias                                                           neutral
# bias:confidence                                                      1
# message                                                        support
# message:confidence                                                   1
# orig__golden                                                       NaN
# audience_gold                                                      NaN
# bias_gold                                                          NaN
# bioid                                                          S001180
# embed                <blockquote class="twitter-tweet" width="450">...
# id                                                         3.39069E+17
# label                 From: Kurt Schrader (Representative from Oregon)
# message_gold                                                       NaN
# source                                                         twitter
# text                 Please join me today in remembering our fallen...
#
#                                                                      3  \
# _unit_id                                                     766192487
# _golden                                                          False
# _unit_state                                                  finalized
# _trusted_judgments                                                   1
# _last_judgment_at                                         8/4/15 21:08
# audience                                                      national
# audience:confidence                                                  1
# bias                                                           neutral
# bias:confidence                                                      1
# message                                                         policy
# message:confidence                                                   1
# orig__golden                                                       NaN
# audience_gold                                                      NaN
# bias_gold                                                          NaN
# bioid                                                          C000880
# embed                <blockquote class="twitter-tweet" width="450">...
# id                                                         2.98528E+17
# label                         From: Michael Crapo (Senator from Idaho)
# message_gold                                                       NaN
# source                                                         twitter
# text                 RT @SenatorLeahy: 1st step toward Senate debat...
#
#                                                                      4
# _unit_id                                                     766192488
# _golden                                                          False
# _unit_state                                                  finalized
# _trusted_judgments                                                   1
# _last_judgment_at                                         8/4/15 21:26
# audience                                                      national
# audience:confidence                                                  1
# bias                                                          partisan
# bias:confidence                                                      1
# message                                                         policy
# message:confidence                                                   1
# orig__golden                                                       NaN
# audience_gold                                                      NaN
# bias_gold                                                          NaN
# bioid                                                          U000038
# embed                <blockquote class="twitter-tweet" width="450">...
# id                                                         4.07643E+17
# label                         From: Mark Udall (Senator from Colorado)
# message_gold                                                       NaN
# source                                                         twitter
# text                 .@amazon delivery #drones show need to update ...

# %% [markdown]
# # Data Cleaning & Initial EDA

# %%
df = raw_df[['bias','message','embed','label','source','text']]
df.head().T
# Out:
#                                                          0  \
# bias                                              partisan
# message                                             policy
# embed    <blockquote class="twitter-tweet" width="450">...
# label       From: Trey Radel (Representative from Florida)
# source                                             twitter
# text     RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...
#
#                                                          1  \
# bias                                              partisan
# message                                             attack
# embed    <blockquote class="twitter-tweet" width="450">...
# label        From: Mitch McConnell (Senator from Kentucky)
# source                                             twitter
# text     VIDEO - #Obamacare:  Full of Higher Costs and ...
#
#                                                          2  \
# bias                                               neutral
# message                                            support
# embed    <blockquote class="twitter-tweet" width="450">...
# label     From: Kurt Schrader (Representative from Oregon)
# source                                             twitter
# text     Please join me today in remembering our fallen...
#
#                                                          3  \
# bias                                               neutral
# message                                             policy
# embed    <blockquote class="twitter-tweet" width="450">...
# label             From: Michael Crapo (Senator from Idaho)
# source                                             twitter
# text     RT @SenatorLeahy: 1st step toward Senate debat...
#
#                                                          4
# bias                                              partisan
# message                                             policy
# embed    <blockquote class="twitter-tweet" width="450">...
# label             From: Mark Udall (Senator from Colorado)
# source                                             twitter
# text     .@amazon delivery #drones show need to update ...

# %%
df['bias'].value_counts()
# Out:
# neutral     3689
# partisan    1311
# Name: bias, dtype: int64

# %%
df['message'].value_counts()
# Out:
# policy          1411
# personal        1170
# support          921
# information      647
# media            277
# attack           172
# constituency     152
# mobilization     129
# other            121
# Name: message, dtype: int64

# %%
#congressmen_2015 = pd.DataFrame(df['label'].unique())

# %%
#type(congressmen_2015)

# %%
#congressmen_2015.to_csv('congressmen_2015.csv')

# %%
def remove_punctuations(text):
    '''Removes punctuation from strings'''
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df['text'] = df.loc[:,'text'].apply(remove_punctuations)
df['label'] = df['label'].str.replace('From: ','')
df['purpose_and_bias'] = df['message'] + '_' + df['bias']
df['text'] = df['text'].str.lower()
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#        bias  message                                              embed  \
# 0  partisan   policy  <blockquote class="twitter-tweet" width="450">...
# 1  partisan   attack  <blockquote class="twitter-tweet" width="450">...
# 2   neutral  support  <blockquote class="twitter-tweet" width="450">...
# 3   neutral   policy  <blockquote class="twitter-tweet" width="450">...
# 4  partisan   policy  <blockquote class="twitter-tweet" width="450">...
#
#                                         label   source  \
# 0    Trey Radel (Representative from Florida)  twitter
# 1     Mitch McConnell (Senator from Kentucky)  twitter
# 2  Kurt Schrader (Representative from Oregon)  twitter
# 3          Michael Crapo (Senator from Idaho)  twitter
# 4          Mark Udall (Senator from Colorado)  twitter
#
#                                                 text purpose_and_bias
# 0  rt nowthisnews rep trey radel r fl slams obama...  policy_partisan
# 1  video  obamacare  full of higher costs and bro...  attack_partisan
# 2  please join me today in remembering our fallen...  support_neutral
# 3  rt senatorleahy 1st step toward senate debate ...   policy_neutral
# 4  amazon delivery drones show need to update law...  policy_partisan

# %%
df['purpose_and_bias'].value_counts()
# Out:
# personal_neutral         1073
# support_neutral           751
# policy_partisan           706
# policy_neutral            705
# information_neutral       565
# media_neutral             247
# support_partisan          170
# attack_partisan           160
# constituency_neutral      129
# other_neutral             117
# personal_partisan          97
# mobilization_neutral       90
# information_partisan       82
# mobilization_partisan      39
# media_partisan             30
# constituency_partisan      23
# attack_neutral             12
# other_partisan              4
# Name: purpose_and_bias, dtype: int64

# %%
congressmen_df = pd.read_csv('congressmen_2015.csv')
congressmen_df.head()
# Out:
#       First       Last                                    congressman  \
# 0  Gregorio     Sablan       Gregorio Sablan (Representative from NA)
# 1    Robert   Aderholt  Robert Aderholt (Representative from Alabama)
# 2     Lamar  Alexander       Lamar Alexander (Senator from Tennessee)
# 3    Justin      Amash    Justin Amash (Representative from Michigan)
# 4      Mark     Amodei       Mark Amodei (Representative from Nevada)
#
#   affiliation
# 0           d
# 1           r
# 2           r
# 3           r
# 4           r

# %%
df = df.merge(congressmen_df, how='left',left_on='label',right_on='congressman')

# %%
df.loc[df.bias == 'partisan', 'target'] = df['affiliation']
df.loc[df.bias == 'neutral', 'target'] = df['bias']

# %%
df.head()
# Out:
#        bias  message                                              embed  \
# 0  partisan   policy  <blockquote class="twitter-tweet" width="450">...
# 1  partisan   attack  <blockquote class="twitter-tweet" width="450">...
# 2   neutral  support  <blockquote class="twitter-tweet" width="450">...
# 3   neutral   policy  <blockquote class="twitter-tweet" width="450">...
# 4  partisan   policy  <blockquote class="twitter-tweet" width="450">...
#
#                                         label   source  \
# 0    Trey Radel (Representative from Florida)  twitter
# 1     Mitch McConnell (Senator from Kentucky)  twitter
# 2  Kurt Schrader (Representative from Oregon)  twitter
# 3          Michael Crapo (Senator from Idaho)  twitter
# 4          Mark Udall (Senator from Colorado)  twitter
#
#                                                 text purpose_and_bias  \
# 0  rt nowthisnews rep trey radel r fl slams obama...  policy_partisan
# 1  video  obamacare  full of higher costs and bro...  attack_partisan
# 2  please join me today in remembering our fallen...  support_neutral
# 3  rt senatorleahy 1st step toward senate debate ...   policy_neutral
# 4  amazon delivery drones show need to update law...  policy_partisan
#
#      First       Last                                 congressman affiliation  \
# 0     Trey      Radel    Trey Radel (Representative from Florida)           r
# 1    Mitch  McConnell     Mitch McConnell (Senator from Kentucky)           r
# 2     Kurt   Schrader  Kurt Schrader (Representative from Oregon)           d
# 3  Michael      Crapo          Michael Crapo (Senator from Idaho)           r
# 4     Mark      Udall          Mark Udall (Senator from Colorado)           d
#
#     target
# 0        r
# 1        r
# 2  neutral
# 3  neutral
# 4        d

# %%
df['target'].value_counts()
# Out:
# neutral    3689
# r           791
# d           490
# i            17
# Name: target, dtype: int64

# %%
len(df[df['target'].isnull()])
# Out:
# 13

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4929 entries, 0 to 4999
# Data columns (total 12 columns):
# bias                4929 non-null object
# message             4929 non-null object
# embed               4929 non-null object
# label               4929 non-null object
# source              4929 non-null object
# text                4929 non-null object
# purpose_and_bias    4929 non-null object
# First               4929 non-null object
# Last                4929 non-null object
# congressman         4929 non-null object
# affiliation         4929 non-null object
# target              4929 non-null object
# dtypes: object(12)
# memory usage: 500.6+ KB

# %% [markdown]
# ## Inputs (X): Tweets
# ## Target (Y): Bias

# %%
import re
def cleanText(text):
    text = text.strip().replace("\n", " ").replace("\r", " ")
    text = replace_contraction(text)
    text = replace_links(text, "link")
    text = remove_numbers(text)
    text = re.sub(r'[,!@#$%^&*)(|/><";:.?\'\\}{]',"",text)
    text = text.lower()
    return text

# %%
X = np.array(df['text'])
y = np.array(df['target'])

# %%
df_copy = df.copy()

# %%
train_set = df_copy.sample(frac=0.75, random_state=0)
test_set = df_copy.drop(train_set.index)

# %%
train_set.shape, test_set.shape
# Out:
# ((3697, 12), (1232, 12))

# %%
train_set['clean_text'] = train_set['text'].apply(lambda x: re.sub(r'http\S+', '', x))

test_set['clean_text'] = test_set['text'].apply(lambda x: re.sub(r'http\S+', '', x))

# %%
#!python -m spacy download en

# %%
# import spaCy's language model
nlp = spacy.load('en', disable=['parser', 'ner'])

# function to lemmatize text
def lemmatization(texts):
    output = []
    for i in texts:
        s = [token.lemma_ for token in nlp(i)]
        output.append(' '.join(s))
    return output

# %%
train_set['clean_text'] = lemmatization(train_set['clean_text'])
test_set['clean_text'] = lemmatization(test_set['clean_text'])

# %%
train_set.sample(10)
# Out:
#           bias   message                                              embed  \
# 4833  partisan  personal  <div id="fb-root"></div> <script>(function(d, ...
# 3042   neutral    policy  <div id="fb-root"></div> <script>(function(d, ...
# 4337   neutral  personal  <div id="fb-root"></div> <script>(function(d, ...
# 2158   neutral   support  <blockquote class="twitter-tweet" width="450">...
# 838    neutral   support  <blockquote class="twitter-tweet" width="450">...
# 4974   neutral     media  <div id="fb-root"></div> <script>(function(d, ...
# 1049   neutral   support  <blockquote class="twitter-tweet" width="450">...
# 2283   neutral   support  <blockquote class="twitter-tweet" width="450">...
# 4813   neutral    policy  <div id="fb-root"></div> <script>(function(d, ...
# 986   partisan    policy  <blockquote class="twitter-tweet" width="450">...
#
#                                                   label    source  \
# 4833            Marc Veasey (Representative from Texas)  facebook
# 3042       Susan Davis (Representative from California)  facebook
# 4337  Ileana Ros-Lehtinen (Representative from Florida)  facebook
# 2158      Brad Schneider (Representative from Illinois)   twitter
# 838   Ileana Ros-Lehtinen (Representative from Florida)   twitter
# 4974        John Yarmuth (Representative from Kentucky)  facebook
# 1049      Jerrold Nadler (Representative from New York)   twitter
# 2283  Lucille Roybal-Allard (Representative from Cal...   twitter
# 4813                Tom Udall (Senator from New Mexico)  facebook
# 986        Bill Cassidy (Representative from Louisiana)   twitter
#
#                                                    text   purpose_and_bias  \
# 4833  tonight iûªll be in miami to speak about comp...  personal_partisan
# 3042  our students deserve a chance to achieve the a...     policy_neutral
# 4337  high schooler marcel bozasûªs ûïiconic board...   personal_neutral
# 2158  hope today illinois joins the growing list of ...    support_neutral
# 838   congrats to new miamiherald publisher alex vil...    support_neutral
# 4974  ill be on foxbusiness shortly after noon to di...      media_neutral
# 1049  proud to standwithpeggy pregnant workers shoul...    support_neutral
# 2283  join me and other healthequity supporters for ...    support_neutral
# 4813  join me today in supporting safer internet day...     policy_neutral
# 986   ocares medical device tax will cost our nation...    policy_partisan
#
#         First           Last  \
# 4833     Marc         Veasey
# 3042    Susan          Davis
# 4337   Ileana   Ros-Lehtinen
# 2158     Brad      Schneider
# 838    Ileana   Ros-Lehtinen
# 4974     John        Yarmuth
# 1049  Jerrold         Nadler
# 2283  Lucille  Roybal-Allard
# 4813      Tom          Udall
# 986      Bill        Cassidy
#
#                                             congressman affiliation   target  \
# 4833            Marc Veasey (Representative from Texas)           d        d
# 3042       Susan Davis (Representative from California)           d  neutral
# 4337  Ileana Ros-Lehtinen (Representative from Florida)           r  neutral
# 2158      Brad Schneider (Representative from Illinois)           d  neutral
# 838   Ileana Ros-Lehtinen (Representative from Florida)           r  neutral
# 4974        John Yarmuth (Representative from Kentucky)           d  neutral
# 1049      Jerrold Nadler (Representative from New York)           d  neutral
# 2283  Lucille Roybal-Allard (Representative from Cal...           d  neutral
# 4813                Tom Udall (Senator from New Mexico)           d  neutral
# 986        Bill Cassidy (Representative from Louisiana)           r        r
#
#                                              clean_text
# 4833  tonight iûªll be in miami to speak about comp...
# 3042  -PRON- student deserve a chance to achieve the...
# 4337  high schooler marcel bozasûªs ûïiconic board...
# 2158  hope today illinois join the grow list of stat...
# 838   congrat to new miamiherald publisher alex vill...
# 4974  ill be on foxbusiness shortly after noon to di...
# 1049  proud to standwithpeggy pregnant worker should...
# 2283  join -PRON- and other healthequity supporter f...
# 4813  join -PRON- today in support safe internet day...
# 986   ocare medical device tax will cost -PRON- nati...

# %%
# Download the module, and uncompress it to the destination folder.
#!curl -L "https://tfhub.dev/google/elmo/2?tf-hub-format=compressed" | tar -zxvC module/module_elmo2

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0620 09:24:09.455492 140735514080128 deprecation.py:323] From /anaconda3/envs/learn-env/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
elmo = hub.Module("module/module_elmo2/", trainable=False)

# %%
def elmo_vectors(x):
    embeddings = elmo(x.tolist(), signature="default", as_dict=True)["elmo"]

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        sess.run(tf.tables_initializer())
    # return average of ELMo features
    return sess.run(tf.reduce_mean(embeddings,1))

# %%
list_train = [train_set[i:i+100] for i in range(0,train_set.shape[0],100)]
list_test = [test_set[i:i+100] for i in range(0,test_set.shape[0],100)]

# %%
#elmo_train = [elmo_vectors(x['clean_text']) for x in list_train]
#elmo_test = [elmo_vectors(x['clean_text']) for x in list_test]

# %%
from keras.engine.input_layer import InputLayer
from keras.models import Sequential

model = Sequential()
model.add(InputLayer(input_shape=(1,), dtype="string"))
model.add(Lambda(ELMoEmbedding, output_shape=(1024, ))) #
model.add(Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(Dense(4, activation='softmax'))

# %% [markdown]
# Output: TensorShape([Dimension(1), Dimension(8), Dimension(1024)])
#
# The output is a 3 dimensional tensor of shape (1, 8, 1024):
#
# The first dimension of this tensor represents the number of training samples. This is 1 in our case
# The second dimension represents the maximum length of the longest string in the input list of strings. Since we have only 1 string in our input list, the size of the 2nd dimension is equal to the length of the string – 8
# The third dimension is equal to the length of the ELMo vector

# %% [markdown]
# # ELMO Embedding in a Simple Neural Network Classifier

# %%
import re
def cleanText(text):
    text = text.strip().replace("\n", " ").replace("\r", " ")
    text = replace_contraction(text)
    text = replace_links(text, "link")
    text = remove_numbers(text)
    text = re.sub(r'[,!@#$%^&*)(|/><";:.?\'\\}{]',"",text)
    text = text.lower()
    return text

# %%
embed = hub.Module("module/module_elmo2")
def ELMoEmbedding(x):
    return embed(tf.squeeze(tf.cast(x, tf.string)), signature="default", as_dict=True)["default"]

# %%
def build_model(): 
    input_text = Input(shape=(1,), dtype="string")
    embedding = Lambda(ELMoEmbedding, output_shape=(1024, ))(input_text)
    dense = Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001))(embedding)
    pred = Dense(1, activation='sigmoid')(dense)
    model = Model(inputs=[input_text], outputs=pred)
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
model_elmo = build_model()
model_elmo.summary()

# %%
with tf.Session() as session:
    K.set_session(session)
    session.run(tf.global_variables_initializer())  
    session.run(tf.tables_initializer())
    history = model_elmo.fit(X, y, epochs=5, batch_size=256, validation_split = 0.2)
    model_elmo.save_weights('./model_elmo_weights.h5')
